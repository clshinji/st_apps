# %% [markdown]
# # スシローアレルギー情報のフィルタリング
# _PDFから表の情報を取得する_
#
# ## 公式サイト https://www.akindo-sushiro.co.jp/menu/allergy.html
#
# 1. マークの見方
# >
# > ●：原材料として使用しています
# >
# > ○：工場で製造ラインを共有しています
#
# 2. 注意事項
# >
# > 本来そのメニューに含まれていない他のアレルギー物質が、工場製造時や店舗調理時に意図せず付着、混入する場合があります。
# >
# > 情報は随時更新しておりますので、常に最新の情報をご覧下さい。
# >
# > 限定メニューなど、掲載されていない商品がある場合があります。

# %%
# !streamlit run main.py

# %%
# !pip install tabula-py

# %%
# モジュールインポート、初期設定

import tabula
import pandas as pd

column_names_pg1 = [
    '区分',
    'メニュー名称',
    '不要',
    '卵',
    '乳成分',
    '小麦',
    'えび',
    'かに',
    'そば',
    '落花生',
    'くるみ',
    'アーモンド',
    'あわび',
    'いか',
    'いくら',
    'オレンジ',
    'カシューナッツ',
    'キウイフルーツ',
    '牛肉',
    'ごま',
    'さけ',
    'さば',
    '大豆',
    '鶏肉',
    'バナナ',
    '豚肉',
    'まつたけ',
    'もも',
    'やまいも',
    'りんご',
    'ゼラチン',
]

column_names_pg2 = [
    '区分',
    'メニュー名称',
    '卵',
    '乳成分',
    '小麦',
    'えび',
    'かに',
    'そば',
    '落花生',
    'くるみ',
    'アーモンド',
    'あわび',
    'いか',
    'いくら',
    'オレンジ',
    'カシューナッツ',
    'キウイフルーツ',
    '牛肉',
    'ごま',
    'さけ',
    'さば',
    '大豆',
    '鶏肉',
    'バナナ',
    '豚肉',
    'まつたけ',
    'もも',
    'やまいも',
    'りんご',
    'ゼラチン',
]

print(f'column counts(p.1):{len(column_names_pg1)}')
print(f'column names (p.1):{column_names_pg1}')

# PDFファイルから表を読み込む
df = tabula.read_pdf('allergy.pdf', pages='all')
# Out:
# column counts(p.1):31
# column names (p.1):['区分', 'メニュー名称', '不要', '卵', '乳成分', '小麦', 'えび', 'かに', 'そば', '落花生', 'くるみ', 'アーモンド', 'あわび', 'いか', 'いくら', 'オレンジ', 'カシューナッツ', 'キウイフルーツ', '牛肉', 'ごま', 'さけ', 'さば', '大豆', '鶏肉', 'バナナ', '豚肉', 'まつたけ', 'もも', 'やまいも', 'りんご', 'ゼラチン']
# Got stderr: 5 08, 2023 10:49:14 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# 5 08, 2023 10:49:14 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# 5 08, 2023 10:49:14 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# 5 08, 2023 10:49:15 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# 5 08, 2023 10:49:15 午後 org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# 情報: Your current java version is: 1.8.0_151
# 5 08, 2023 10:49:15 午後 org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# 情報: To get higher rendering speed on old java 1.8 or 9 versions,
# 5 08, 2023 10:49:15 午後 org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# 情報:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# 5 08, 2023 10:49:15 午後 org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# 情報:   or
# 5 08, 2023 10:49:15 午後 org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# 情報:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# 5 08, 2023 10:49:15 午後 org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# 情報:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")
# 5 08, 2023 10:49:17 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# 5 08, 2023 10:49:17 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# 5 08, 2023 10:49:17 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# 5 08, 2023 10:49:17 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored

# %%
# 読み込まれたデータの確認
print(f'data type(p.1): {type(df[0])}')

# ページ数を取得する
page_counts = len(df)
print(f'page counts:{page_counts}')

# 全ページのカラム数が一致していることを確認する
# p.1のみ31列として読み込まれることが多い？
for i in range(len(df)):
    df_org = df[i].copy()
    # print(f'column names :{df_org.columns}')
    print(f'page No.:{i}, column counts:{len(df_org.columns)}')

# df check -> p.1のデータフレームだけ表示してみる
df[0].head()
# Out:
# data type(p.1): <class 'pandas.core.frame.DataFrame'>
# page counts:8
# page No.:0, column counts:31
# page No.:1, column counts:30
# page No.:2, column counts:30
# page No.:3, column counts:30
# page No.:4, column counts:30
# page No.:5, column counts:30
# page No.:6, column counts:30
# page No.:7, column counts:30
#   Unnamed: 0 Unnamed: 1 Unnamed: 2    卵    乳    小    え    か    そ    落  ...  \
# 0        NaN        NaN        NaN  NaN    成    麦    び    に    ば    花  ...
# 1        NaN        NaN        NaN  NaN    分  NaN  NaN  NaN  NaN    生  ...
# 2         区分        NaN     メニュー名称  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 3        NaN        NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 4        NaN        NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
#    さ.1    大    鶏    バ    豚    ま    も    や    り    ゼ
# 0    ば    豆    肉    ナ    肉    つ    も    ま    ん    ラ
# 1  NaN  NaN  NaN    ナ  NaN    た  NaN    い    ご    チ
# 2  NaN  NaN  NaN  NaN  NaN    け  NaN    も  NaN    ン
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 31 columns]

# %%
# 1ページ目だけ先に読み込む
# 1ページ目の表を取得する
df_org = df[0].copy()
# カラム名を設定する
df_org.columns = column_names_pg1

# 「'●', '○'」を含まない行を削除する
df_allergy = df_org[df_org[column_names_pg1].isin(['●', '○']).any(axis=1)].copy()

# 1ページ目だけ31ページある場合に実行
# 1ページ目の不要な列を削除する
df_allergy = df_allergy.drop(columns='不要')


# 2ページ目以降の表を取得して結合する
for i in range(1, len(df)):
    df_org = df[i].copy()
    df_org.columns = column_names_pg2
    # print(f'column names :{df_org.columns}')
    print(f'page No.:{i}, column counts:{len(df_org.columns)}')
    # 「'●', '○'」を含まない行を削除する
    df_org = df_org[df_org[column_names_pg2].isin(['●', '○']).any(axis=1)].copy()
    # df_allergyにdf_orgを縦方向に連結する
    df_allergy = pd.concat([df_allergy, df_org], axis=0, ignore_index=True).copy()
    print(f' -> df_allergy shape: {df_allergy.shape}')

df_allergy
# Out:
# page No.:1, column counts:30
#  -> df_allergy shape: (55, 30)
# page No.:2, column counts:30
#  -> df_allergy shape: (86, 30)
# page No.:3, column counts:30
#  -> df_allergy shape: (117, 30)
# page No.:4, column counts:30
#  -> df_allergy shape: (148, 30)
# page No.:5, column counts:30
#  -> df_allergy shape: (179, 30)
# page No.:6, column counts:30
#  -> df_allergy shape: (210, 30)
# page No.:7, column counts:30
#  -> df_allergy shape: (230, 30)
#         区分                  メニュー名称    卵  乳成分 小麦  えび   かに  そば  落花生  くるみ  ...  \
# 0       寿司                     赤えび  NaN  NaN  ○    ●  NaN  NaN  NaN  NaN  ...
# 1       寿司                  炙り3貫盛り    ○    ○  ○    ●    ○  NaN  NaN  NaN  ...
# 2       寿司                   炙り牛タン  NaN    ○  ○  NaN  NaN  NaN  NaN  NaN  ...
# 3       寿司            炙りサーモンバジルチーズ    ●    ●  ○    ○    ○  NaN  NaN  NaN  ...
# 4       寿司                   炙り上穴子    ○    ○  ●    ○    ○  NaN    ○  NaN  ...
# ..     ...                     ...  ...  ... ..  ...  ...  ...  ...  ...  ...
# 225  デリバリー             デリ)まぐろサーモン丼    ○    ○  ○    ○    ○  NaN  NaN  NaN  ...
# 226  デリバリー            デリ)まぐろてんこ盛り丼    ○    ○  ○    ○  NaN  NaN  NaN  NaN  ...
# 227  デリバリー             デリ)活〆ひらまさ3貫  NaN  NaN  ○    ○    ○  NaN  NaN  NaN  ...
# 228  デリバリー  デリ)ダブル貝柱 活〆ヒラマサ 特ネタ中トロ  NaN  NaN  ○    ○    ○  NaN  NaN  NaN  ...
# 229  デリバリー              デリ)ダブル貝柱3貫  NaN  NaN  ○  NaN    ○  NaN  NaN  NaN  ...
#
#      さば 大豆   鶏肉 バナナ 豚肉 まつたけ   もも やまいも りんご ゼラチン
# 0    NaN  ○  NaN  NaN  ○  NaN  NaN  NaN    ○   NaN
# 1      ○  ○  NaN  NaN  ○  NaN  NaN  NaN    ○   NaN
# 2    NaN  ○    ○  NaN  ○  NaN  NaN  NaN    ○     ○
# 3      ○  ●    ○    ○  ○  NaN  NaN  NaN    ●     ○
# 4      ○  ●    ○  NaN  ○  NaN    ○  NaN    ○     ○
# ..   ... ..  ...  ... ..  ...  ...  ...  ...   ...
# 225    ○  ○  NaN  NaN  ○  NaN  NaN    ○    ○     ○
# 226  NaN  ○  NaN  NaN  ○  NaN  NaN    ○    ○     ○
# 227    ○  ○  NaN  NaN  ○  NaN  NaN  NaN    ○   NaN
# 228    ○  ○  NaN  NaN  ○  NaN  NaN  NaN    ○   NaN
# 229    ○  ○  NaN  NaN  ○  NaN  NaN  NaN    ○   NaN
#
# [230 rows x 30 columns]

# %%
# 作成したdf_allergyをcsv形式で保存する
df_allergy.to_csv('allergy_table.csv')
