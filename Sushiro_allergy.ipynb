# %% [markdown]
# # スシローアレルギー情報のフィルタリング
# _PDFから表の情報を取得する_
#
# ## 公式サイト https://www.akindo-sushiro.co.jp/menu/allergy.html
#
# 1. マークの見方
# >
# > ●：原材料として使用しています
# >
# > ○：工場で製造ラインを共有しています
#
# 2. 注意事項
# >
# > 本来そのメニューに含まれていない他のアレルギー物質が、工場製造時や店舗調理時に意図せず付着、混入する場合があります。
# >
# > 情報は随時更新しておりますので、常に最新の情報をご覧下さい。
# >
# > 限定メニューなど、掲載されていない商品がある場合があります。

# %%
# !streamlit run main.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.20.10.4:8501
#
#   For better performance, install the Watchdog module:
#
#   $ xcode-select --install
#   $ pip install watchdog
#
# ^C
#   Stopping...

# %%
# !pip install tabula-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting tabula-py
#   Downloading tabula_py-2.7.0-py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 27.1 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tabula-py) (1.22.3)
# Requirement already satisfied: distro in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tabula-py) (1.8.0)
# Requirement already satisfied: pandas>=0.25.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tabula-py) (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas>=0.25.3->tabula-py) (2022.7)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=0.25.3->tabula-py) (1.16.0)
# Installing collected packages: tabula-py
# Successfully installed tabula-py-2.7.0

# %%
# モジュールインポート、初期設定

import tabula
import pandas as pd

column_names_pg1 = [
    '区分',
    'メニュー名称',
    '不要',
    '卵',
    '乳成分',
    '小麦',
    'えび',
    'かに',
    'そば',
    '落花生',
    'くるみ',
    'アーモンド',
    'あわび',
    'いか',
    'いくら',
    'オレンジ',
    'カシューナッツ',
    'キウイフルーツ',
    '牛肉',
    'ごま',
    'さけ',
    'さば',
    '大豆',
    '鶏肉',
    'バナナ',
    '豚肉',
    'まつたけ',
    'もも',
    'やまいも',
    'りんご',
    'ゼラチン',
]

column_names_pg2 = [
    '区分',
    'メニュー名称',
    '卵',
    '乳成分',
    '小麦',
    'えび',
    'かに',
    'そば',
    '落花生',
    'くるみ',
    'アーモンド',
    'あわび',
    'いか',
    'いくら',
    'オレンジ',
    'カシューナッツ',
    'キウイフルーツ',
    '牛肉',
    'ごま',
    'さけ',
    'さば',
    '大豆',
    '鶏肉',
    'バナナ',
    '豚肉',
    'まつたけ',
    'もも',
    'やまいも',
    'りんご',
    'ゼラチン',
]

print('pattern1')
print(f'column counts(p.1):{len(column_names_pg1)}')
print(f'column names (p.1):{column_names_pg1}')

print('pattern2')
print(f'column counts(p.1):{len(column_names_pg2)}')
print(f'column names (p.1):{column_names_pg2}')

# PDFファイルから表を読み込む
df = tabula.read_pdf('allergy.pdf', pages='all')
# Out:
# pattern1
# column counts(p.1):31
# column names (p.1):['区分', 'メニュー名称', '不要', '卵', '乳成分', '小麦', 'えび', 'かに', 'そば', '落花生', 'くるみ', 'アーモンド', 'あわび', 'いか', 'いくら', 'オレンジ', 'カシューナッツ', 'キウイフルーツ', '牛肉', 'ごま', 'さけ', 'さば', '大豆', '鶏肉', 'バナナ', '豚肉', 'まつたけ', 'もも', 'やまいも', 'りんご', 'ゼラチン']
# pattern2
# column counts(p.1):30
# column names (p.1):['区分', 'メニュー名称', '卵', '乳成分', '小麦', 'えび', 'かに', 'そば', '落花生', 'くるみ', 'アーモンド', 'あわび', 'いか', 'いくら', 'オレンジ', 'カシューナッツ', 'キウイフルーツ', '牛肉', 'ごま', 'さけ', 'さば', '大豆', '鶏肉', 'バナナ', '豚肉', 'まつたけ', 'もも', 'やまいも', 'りんご', 'ゼラチン']
# Got stderr: May 12, 2023 11:17:50 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# May 12, 2023 11:17:50 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# May 12, 2023 11:17:50 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# May 12, 2023 11:17:50 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# May 12, 2023 11:17:52 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# May 12, 2023 11:17:52 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# May 12, 2023 11:17:52 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# May 12, 2023 11:17:52 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored

# %%
# 読み込まれたデータの確認
print(f'data type(p.1): {type(df[0])}')

# ページ数を取得する
page_counts = len(df)
print(f'page counts:{page_counts}')

# 全ページのカラム数が一致していることを確認する
# p.1のみ31列として読み込まれることが多い？
for i in range(len(df)):
    df_org = df[i].copy()
    # print(f'column names :{df_org.columns}')
    print(f'page No.:{i}, column counts:{len(df_org.columns)}')

# df check -> p.1のデータフレームだけ表示してみる
df[0].head(10)
# Out:
# data type(p.1): <class 'pandas.core.frame.DataFrame'>
# page counts:9
# page No.:0, column counts:30
# page No.:1, column counts:30
# page No.:2, column counts:30
# page No.:3, column counts:30
# page No.:4, column counts:30
# page No.:5, column counts:30
# page No.:6, column counts:30
# page No.:7, column counts:30
# page No.:8, column counts:30
#   Unnamed: 0      Unnamed: 1    卵    乳    小    え    か    そ    落    く  ...  \
# 0        NaN             NaN  NaN    成    麦    び    に    ば    花    る  ...
# 1        NaN             NaN  NaN    分  NaN  NaN  NaN  NaN    生    み  ...
# 2         区分          メニュー名称  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 3        NaN             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 4        NaN             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 5        NaN             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 6        NaN             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 7         寿司        青森産生サーモン    ○    ○    ○    ○    ○  NaN  NaN  NaN  ...
# 8         寿司             赤えび  NaN  NaN    ○    ●  NaN  NaN  NaN  NaN  ...
# 9         寿司  アカバナかんぱち 竜田にぎり    ●    ●    ●    ○    ○  NaN  NaN  NaN  ...
#
#    さ.1    大    鶏    バ    豚    ま    も    や    り    ゼ
# 0    ば    豆    肉    ナ    肉    つ    も    ま    ん    ラ
# 1  NaN  NaN  NaN    ナ  NaN    た  NaN    い    ご    チ
# 2  NaN  NaN  NaN  NaN  NaN    け  NaN    も  NaN    ン
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 7    ○    ○  NaN  NaN    ○  NaN  NaN  NaN    ○  NaN
# 8  NaN    ○  NaN  NaN    ○  NaN  NaN  NaN    ○  NaN
# 9    ○    ●    ○  NaN    ○  NaN    ○    ○    ●    ○
#
# [10 rows x 30 columns]

# %%
# 1ページ目だけ先に読み込む
# 1ページ目の表を取得する
df_org = df[0].copy()
print(f"p.1 columns counts = {len(df_org.columns)}")

if len(df[0].columns) == 31:
    print("column_names_pg1 apply")
    # 1ページ目だけ31ページある場合に実行
    # カラム名を設定する
    df_org.columns = column_names_pg1
    # 「'●', '○'」を含まない行を削除する
    df_allergy = df_org[df_org[column_names_pg1].isin(['●', '○']).any(axis=1)].copy()
    # 1ページ目の不要な列を削除する
    df_allergy = df_allergy.drop(columns='不要')
else:
    print("column_names_pg2 apply")
    # カラム名を設定する
    df_org.columns = column_names_pg2
    # 「'●', '○'」を含まない行を削除する
    df_allergy = df_org[df_org[column_names_pg2].isin(['●', '○']).any(axis=1)].copy()

# 2ページ目以降の表を取得して結合する
for i in range(1, len(df)):
    df_org = df[i].copy()
    df_org.columns = column_names_pg2
    # print(f'column names :{df_org.columns}')
    print(f'page No.:{i}, column counts:{len(df_org.columns)}')
    # 「'●', '○'」を含まない行を削除する
    df_org = df_org[df_org[column_names_pg2].isin(['●', '○']).any(axis=1)].copy()
    # df_allergyにdf_orgを縦方向に連結する
    df_allergy = pd.concat([df_allergy, df_org], axis=0, ignore_index=True).copy()
    print(f' -> df_allergy shape: {df_allergy.shape}')

df_allergy
# Out:
# p.1 columns counts = 30
# column_names_pg2 apply
# page No.:1, column counts:30
#  -> df_allergy shape: (55, 30)
# page No.:2, column counts:30
#  -> df_allergy shape: (86, 30)
# page No.:3, column counts:30
#  -> df_allergy shape: (117, 30)
# page No.:4, column counts:30
#  -> df_allergy shape: (148, 30)
# page No.:5, column counts:30
#  -> df_allergy shape: (179, 30)
# page No.:6, column counts:30
#  -> df_allergy shape: (210, 30)
# page No.:7, column counts:30
#  -> df_allergy shape: (241, 30)
# page No.:8, column counts:30
#  -> df_allergy shape: (242, 30)
#         区分          メニュー名称    卵  乳成分 小麦 えび   かに  そば  落花生  くるみ  ...  さば 大豆  \
# 0       寿司        青森産生サーモン    ○    ○  ○   ○    ○  NaN  NaN  NaN  ...    ○  ○
# 1       寿司             赤えび  NaN  NaN  ○   ●  NaN  NaN  NaN  NaN  ...  NaN  ○
# 2       寿司  アカバナかんぱち 竜田にぎり    ●    ●  ●   ○    ○  NaN  NaN  NaN  ...    ○  ●
# 3       寿司          穴子3貫盛り    ○    ○  ●   ○    ○  NaN    ○  NaN  ...    ○  ●
# 4       寿司          炙り3貫盛り    ○    ○  ○   ●    ○  NaN  NaN  NaN  ...    ○  ○
# ..     ...             ...  ...  ... ..  ..  ...  ...  ...  ...  ...  ... ..
# 237  デリバリー     デリ)まぐろサーモン丼    ○    ○  ○   ○    ○  NaN  NaN  NaN  ...    ○  ○
# 238  デリバリー    デリ)まぐろてんこ盛り丼    ○    ○  ○   ○  NaN  NaN  NaN  NaN  ...  NaN  ○
# 239  デリバリー     デリ)青森産生サーモン    ○    ○  ○   ○    ○  NaN  NaN  NaN  ...    ○  ○
# 240  デリバリー     デリ)活〆ひらまさ3貫  NaN  NaN  ○   ○    ○  NaN  NaN  NaN  ...    ○  ○
# 241  デリバリー    デリ)マーラー風3貫盛り    ●    ○  ●   ●    ○  NaN  NaN  NaN  ...    ○  ●
#
#       鶏肉 バナナ 豚肉 まつたけ   もも やまいも りんご ゼラチン
# 0    NaN  NaN  ○  NaN  NaN  NaN    ○   NaN
# 1    NaN  NaN  ○  NaN  NaN  NaN    ○   NaN
# 2      ○  NaN  ○  NaN    ○    ○    ●     ○
# 3      ○  NaN  ○  NaN    ○  NaN    ○     ○
# 4    NaN  NaN  ○  NaN  NaN  NaN    ○   NaN
# ..   ...  ... ..  ...  ...  ...  ...   ...
# 237  NaN  NaN  ○  NaN  NaN    ○    ○     ○
# 238  NaN  NaN  ○  NaN  NaN    ○    ○     ○
# 239  NaN  NaN  ○  NaN  NaN  NaN    ○   NaN
# 240  NaN  NaN  ○  NaN  NaN  NaN    ○   NaN
# 241    ○  NaN  ○  NaN  NaN  NaN    ●     ○
#
# [242 rows x 30 columns]

# %%
# 作成したdf_allergyをcsv形式で保存する
df_allergy.to_csv('allergy_table.csv')
